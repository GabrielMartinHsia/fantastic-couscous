# %% [markdown]
# # EE 538 - Setup
#
# This is a record of how we set up to code C++ and handle repositories for the semester...
#
# * GitHub
# * VisualStudio
# * Homebrew/Bazel

# %% [markdown]
# ## GitHub
#
# user: GabrielMartinHsia
# primary email: martinhs@usc.edu
#
# ... Need to install git on local machine, here's how:
#
# https://github.com/cli/cli#installation
#
# ... use `conda`, like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ... so, I tried copy/pasting the chunk of github code to create a new repository:

# %% [markdown]
# `echo "# EE538" >> README.md`
#
# `git init`
#
# `git add README.md`
#
# `git commit -m "first commit"`
#
# `git branch -M main`
#
# `git remote add origin https://github.com/GabrielMartinHsia/EE538.git`
#
# `git push -u origin main`

# %% [markdown]
# and just got a bunch of `'"git" command not recognized, use sudo apt blah blah to install...'`
#
# so... here's trying that...
#
# ok, well, that didn't work either.
#
# OK, so, let's just install git directly (not via conda), as directed by link from github:
#
# https://git-scm.com/download/linux

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# hmmm... idk if that worked... no "success" message. Did it get hung up "Processing triggers for man-db..."???
#
# Well, that seems to have worked... I have successfully cloned a repository, made changes in Visual Studio Code, committed changes and pushed back to github.

# %% [markdown]
# ## Bazel
#
# I have no idea what this is... something for testing code? Anyway, here goes...
#
# https://docs.bazel.build/versions/4.2.0/install-ubuntu.html
#
# taking the first (recommended) option:
#
# https://docs.bazel.build/versions/4.2.0/install-bazelisk.html

# %% [markdown]
# ### Step 1:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# First, tried copying the whole block pictured above, and then doing CTRL+SHIFT+ENTER at CLI... and nothing happend.
#
# So then I tried typing it line-by-line...
#
# Here's the first line:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# but then I ran into trouble at:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# and then realized I *could* just copy the whole block, and then *right-click --> paste* at the CLI... like this:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ... so... maybe that worked?

# %% [markdown]
# ### Step 2: Install and Update Bazel

# %% [markdown]
# ... just do the FIRST line of the following...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ... and hyeah... that's a looooooonnnng bunch of CLI output. Looks like it worked though. We'll see?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Step 3: Install a JDK (Optional)
#
# ... I'm not doing this, since I'm not interested in Java. Goodbye.
